# %% [markdown]
# # Main.py
#
# ### Import requred modules

# %%
from pandas import read_csv

# %% [markdown]
# ## This function gives an overview of the dataset and the percentage of Fraudulent transactions in the set.

# %%
def transactions_info():
    dataset = read_csv('creditcard.csv')
    transactions = len(dataset)
    notfraud = len(dataset[dataset.Class == 0])
    fraud = len(dataset[dataset.Class == 1])
    percentage = round(fraud / transactions * 100, 2)
    print('total: '+str(transactions)+'\nfraud: '+str(fraud)+'\npercentage fraud: '+str(percentage)+'%')

# %%
transactions_info() #gives stats on the dataset
# Out:
# total: 284807
# fraud: 492
# percentage fraud: 0.17%

# %% [markdown]
# ## The user is given the option to select which models should be trained and then the subprogram for each e.g. XGBoost.py is run.
# ### The models are trained for each one selected and saved as a .sav file under the 'Models/' directory for persistance.
#
# Please note: Due to the limitations of installing GraphViz on Jupyter Notebooks the function to display the tree when training the Random Forest Classifier will give an error. Please select 'n', an example output from the full program where graphviz was installed locally can be found under 'Analysis/RFC/Tree.png'.

# %%
import Train_models
# Out:
# 1.DecisionTree
# 2. Random Forest Classifier
# 3. XGBoost
# a. All Models
# [example: '1,2']..: 2
# --- Training   RFCModel   ---
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# ...

# %% [markdown]
# ## This loads the .sav file for each model specified and makes predictions for each transaction in the 'creditcards.csv' data. Rows that are classed as suspicious are printed to the console and saved in CSV form under the 'Analysis/' directory for each model. '~/Analysis/Detected_[Model Name].csv'.

# %%
import predict
